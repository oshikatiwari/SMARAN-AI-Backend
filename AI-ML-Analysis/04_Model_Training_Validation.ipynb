# %% [markdown]
# # SIH26003: Model Training, Validation & Pipeline Export
# Trains the ensemble ML pipeline for CPS scoring, adaptive difficulty classification, and impairment risk assessment.

# %%
import train_model

if __name__ == '__main__':
    train_model.train_and_export_models()
