# %% [markdown]
# # SIH26003: Baseline Cognitive Impairment Classification Experiment
# Evaluates baseline Machine Learning models for cognitive impairment risk assessment.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import classification_report, accuracy_score

df = pd.read_csv("dataset/kaggle_dementia_cognitive_game_telemetry.csv")
print("Baseline model setup complete.")
