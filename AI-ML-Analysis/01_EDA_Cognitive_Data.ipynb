# %% [markdown]
# # SIH26003: SMARAN AI - Exploratory Data Analysis (EDA)
# This notebook performs exploratory data analysis on the Kaggle cognitive game telemetry dataset used to train SMARAN's adaptive difficulty engine.

# %%
import pandas as pd
import numpy as np
from pathlib import Path

# Load Kaggle Telemetry Dataset
dataset_path = Path("dataset/kaggle_dementia_cognitive_game_telemetry.csv")
df = pd.read_csv(dataset_path)
print(f"Dataset Shape: {df.shape}")
df.head()

# %%
# Summary Statistics
df.describe()
