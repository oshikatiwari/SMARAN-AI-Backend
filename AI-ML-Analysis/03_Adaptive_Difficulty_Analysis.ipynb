# %% [markdown]
# # SIH26003: Adaptive Difficulty Analysis & Simulation
# Analyzes game-session telemetry metrics to model optimal difficulty progression transitions.

# %%
import pandas as pd
import numpy as np
import joblib

df = pd.read_csv("dataset/kaggle_dementia_cognitive_game_telemetry.csv")
print("Adaptive difficulty dataset loaded.")
